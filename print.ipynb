# %% [markdown]
# **print**

# %%
print('welcome to python')
# Out:
# welcome to python

# %%
print("welcome to python")
# Out:
# welcome to python

# %%
print('welcome','to','python')
# Out:
# welcome to python

# %%
print("welcome\nto\n\npython")
# Out:
# welcome
# to
#
# python

# %%
print("welcome\tto\t\tpython")
# Out:
# welcome	to		python

# %%
print("welcome\\to\\\\python")
# Out:
# welcome\to\\python

# %%
print("welcome\'to\'\'python")
# Out:
# welcome'to''python

# %%
print("welcome\"to\"\"python")
# Out:
# welcome"to""python

# %%
print('sum is' , 7+3)
# Out:
# sum is 10
